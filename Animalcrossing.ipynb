# %% [markdown]
# <a href="https://colab.research.google.com/github/secetindere/Cedricode/blob/main/Animalcrossing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub
path = kagglehub.dataset_download("jessicali9530/animal-crossing-new-horizons-nookplaza-dataset")
# Out:
# Using Colab cache for faster access to the 'animal-crossing-new-horizons-nookplaza-dataset' dataset.

# %% [markdown]
# # Task
# Load and inspect the Animal Crossing New Horizons dataset from `'/kaggle/input/animal-crossing-new-horizons-nookplaza-dataset'` to prepare for user-specified analysis or visualization.

# %% [markdown]
# ## Load Data
#
# ### Subtask:
# Load the Animal Crossing New Horizons dataset from the downloaded path into a pandas DataFrame.

# %% [markdown]
# **Reasoning**:
# To load the dataset, I first need to import the pandas library, which is essential for data manipulation in Python.

# %%
import pandas as pd
print("pandas imported successfully.")
# Out:
# pandas imported successfully.

# %% [markdown]
# **Reasoning**:
# To identify the correct CSV file, I need to list the files within the directory specified by the `path` variable. This requires importing the `os` module and using `os.listdir()`.

# %%
import os
print(os.listdir(path))
# Out:
# ['construction.csv', 'bottoms.csv', 'accessories.csv', 'insects.csv', 'floors.csv', 'shoes.csv', 'wall-mounted.csv', 'achievements.csv', 'umbrellas.csv', 'rugs.csv', 'housewares.csv', 'art.csv', 'reactions.csv', 'miscellaneous.csv', 'dress-up.csv', 'photos.csv', 'bags.csv', 'villagers.csv', 'recipes.csv', 'socks.csv', 'fossils.csv', 'fencing.csv', 'tops.csv', 'wallpaper.csv', 'music.csv', 'posters.csv', 'other.csv', 'headwear.csv', 'tools.csv', 'fish.csv']

# %% [markdown]
# **Reasoning**:
# Based on the listed files, I will load the `villagers.csv` file into a pandas DataFrame, as it represents a core component of the Animal Crossing New Horizons game and seems like a suitable default interpretation for 'the Animal Crossing New Horizons dataset' in this context. I will construct the full path to this file.

# %%
file_name = "villagers.csv"
df = pd.read_csv(os.path.join(path, file_name))
print(f"Successfully loaded {file_name} into a DataFrame.")
df.head()
# Out:
# Successfully loaded villagers.csv into a DataFrame.
#       Name    Species  Gender Personality    Hobby Birthday Catchphrase  \
# 0  Admiral       Bird    Male      Cranky   Nature   27-Jan     aye aye
# 1  Agent S   Squirrel  Female       Peppy  Fitness    2-Jul    sidekick
# 2    Agnes        Pig  Female  Big Sister     Play   21-Apr     snuffle
# 3       Al    Gorilla    Male        Lazy  Fitness   18-Oct     ayyyeee
# 4  Alfonso  Alligator    Male        Lazy     Play    9-Jun    it'sa me
#
#    Favorite Song Style 1  Style 2 Color 1 Color 2               Wallpaper  \
# 0     Steep Hill    Cool     Cool   Black    Blue          dirt-clod wall
# 1  Go K.K. Rider  Active   Simple    Blue   Black           concrete wall
# 2     K.K. House  Simple  Elegant    Pink   White  gray molded-panel wall
# 3  Go K.K. Rider  Active   Active     Red   White           concrete wall
# 4    Forest Life  Simple   Simple     Red    Blue    yellow playroom wall
#
# ...

# %% [markdown]
# ## Inspect Data
#
# ### Subtask:
# Display the first few rows, columns, and data types of the loaded dataset to understand its structure.

# %% [markdown]
# **Reasoning**:
# To understand the structure of the loaded dataset, I will display the first few rows, the column names, and their respective data types using `df.head()`, `df.columns`, and `df.info()`.

# %%
print("First 5 rows of the DataFrame:")
print(df.head())

print("\nColumn names:")
print(df.columns)

print("\nDataFrame Info (data types and non-null counts):")
df.info()
# Out:
# First 5 rows of the DataFrame:
#       Name    Species  Gender Personality    Hobby Birthday Catchphrase  \
# 0  Admiral       Bird    Male      Cranky   Nature   27-Jan     aye aye
# 1  Agent S   Squirrel  Female       Peppy  Fitness    2-Jul    sidekick
# 2    Agnes        Pig  Female  Big Sister     Play   21-Apr     snuffle
# 3       Al    Gorilla    Male        Lazy  Fitness   18-Oct     ayyyeee
# 4  Alfonso  Alligator    Male        Lazy     Play    9-Jun    it'sa me
#
#    Favorite Song Style 1  Style 2 Color 1 Color 2               Wallpaper  \
# 0     Steep Hill    Cool     Cool   Black    Blue          dirt-clod wall
# 1  Go K.K. Rider  Active   Simple    Blue   Black           concrete wall
# 2     K.K. House  Simple  Elegant    Pink   White  gray molded-panel wall
# 3  Go K.K. Rider  Active   Active     Red   White           concrete wall
# 4    Forest Life  Simple   Simple     Red    Blue    yellow playroom wall
#
# ...

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Ask the user what specific analysis or visualization they would like to perform on the Animal Crossing dataset.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The `villagers.csv` dataset, part of the Animal Crossing New Horizons collection, was successfully loaded into a pandas DataFrame.
# *   The DataFrame contains 391 entries and 17 columns.
# *   All columns are of the `object` data type, primarily storing string or mixed data.
# *   There are no missing values across any of the columns in the loaded dataset, as all 391 entries are non-null for every column.
# *   Key columns include 'Name', 'Species', 'Gender', 'Personality', 'Hobby', 'Birthday', 'Catchphrase', 'Favorite Song', 'Style 1', 'Style 2', 'Color 1', 'Color 2', 'Wallpaper', 'Flooring', 'Furniture List', 'Filename', and 'Unique Entry ID'.
#
# ### Insights or Next Steps
#
# *   The dataset is well-structured and clean, with no missing values, making it ready for direct analysis or visualization.
# *   The next logical step is to ask the user for specific analysis or visualization tasks they would like to perform on this `villagers.csv` dataset, given its comprehensive nature covering villager attributes.
